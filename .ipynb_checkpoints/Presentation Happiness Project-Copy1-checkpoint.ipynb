# %% [markdown]
# # What makes people happy?
#
# The `World Happiness Report` is a landmark survey of the state of global happiness that ranks 156 countries by how happy their citizens perceive themselves to be. Over the last year’s, `World Happiness Report` focuses on happiness and the community: how happiness has evolved over the past dozen years, with a focus on the technologies, social norms, conflicts and government policies that have driven those changes.
#
# ![image.png](attachment:image.png)
#
#
# **Dataset information**
#
#     The information in the datasets is based on answers to the most life evaluation address inquired within the survey. This address, known as the Cantril step, asks respondents to think of a step with the most excellent conceivable life for them being a 10 and the most exceedingly bad conceivable life being a and to rate their claim current lives on that scale.
#
#
# The Happiness Score is explained by the following factors:
#
# - `Overall rank`: happiness rank of the different countries
# - `Country or region`
# - `Score`:  is a national average of the responses to the main life evaluation question asked in the Gallup World Poll (GWP), which uses the Cantril Ladder. Ranges from [0-10]
# - `GDP per capita`
# - `Healthy Life Expectancy`: score that goes from [0-1], being 1 the ones that have more confidence in terms of healthy life
# - `Social support`: it indicates how people are appreciating the social support by governments, and it that ranges from [0-2]
# - `Freedom to make life choices` score that ranges from 0 to 1, being 1 the ones that feel more free
# - `Generosity`:score that ranges from 0 to 1, being 1 the ones that feel more generosity
# - `Perceptions of corruption`: perception of corruption on the country that it goes from  0 to 1. The higher this value is the lower perception of corruption
# - `year`
#
#
# >dataset: `happiness_clean.csv`

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert (0,"/content/drive/MyDrive/EDA_Story telling BI_moduleProject/Project 1/Vanda and Guio/_functions_")
from Functions_EDA import *

# %%
happy = pd.read_csv('/content/drive/MyDrive/EDA_Story telling BI_moduleProject/Project 1/Vanda and Guio/happiness_clean.csv')

# %%
happy.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
happy.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                         0.681       0.202                      0.393  2018
# 1                         0.686       0.286                      0.340  2018
# 2                         0.683       0.284                      0.408  2018
# 3                         0.677       0.353                      0.138  2018
# 4                         0.660       0.256                      0.357  2018
# 5                         0.638       0.333                      0.295  2018
# 6                         0.653       0.321                      0.291  2018
# 7                         0.669       0.365                      0.389  2018
# 8                         0.659       0.285                      0.383  2018
# 9                         0.647       0.361                      0.302  2018

# %% [markdown]
# 1. Introduction to the problem
#     - Not all records have data for both years 2018 and 2019
#     - Health data are missing in most of countries studied
#     - Subjectivity of the data
#     - Data had uneven scoring scales

# %% [markdown]
# 2. Solutions
#
#   - Data cleaning
#   - Erase health criteria for which we do not have enough data
#   - Scaling

# %% [markdown]
# 3. Hyphotheses:
#
#   - Perception of corruption is less significant to bring happiness to the country
#   - All countries perceive themselves as generous equally
#   - Social support is the most important index of all
#   - Asian countries and African countries have similar rate of freedom to make life choices
#   - Social support and sense of freedom are interdependent

# %% [markdown]
# ### **Hypothesis 1: Perception of corruption is less significant to bring happiness to the country.**

# %%
happy_2018 = happy[happy['year'] == 2018].sort_values(by = 'Overall rank')
happy_2018
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Finland  7.632           1.305           1.592
# 1               2            Norway  7.594           1.456           1.582
# 2               3           Denmark  7.555           1.351           1.590
# 3               4           Iceland  7.495           1.343           1.644
# 4               5       Switzerland  7.487           1.420           1.549
# ..            ...               ...    ...             ...             ...
# 143           151            Rwanda  3.408           0.332           0.896
# 144           152             Yemen  3.355           0.442           1.073
# 145           153          Tanzania  3.303           0.455           0.991
# 146           154       South Sudan  3.254           0.337           0.608
# 147           156           Burundi  2.905           0.091           0.627
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                           0.681       0.202                      0.393  2018
# 1                           0.686       0.286                      0.340  2018
# 2                           0.683       0.284                      0.408  2018
# 3                           0.677       0.353                      0.138  2018
# 4                           0.660       0.256                      0.357  2018
# ..                            ...         ...                        ...   ...
# 143                         0.636       0.200                      0.444  2018
# 144                         0.244       0.083                      0.064  2018
# 145                         0.481       0.270                      0.097  2018
# 146                         0.112       0.224                      0.106  2018
# 147                         0.065       0.149                      0.076  2018
#
# [148 rows x 9 columns]

# %%
happy_2018['Perceptions of corruption'].describe()
# Out:
# count    148.000000
# mean       0.113324
# std        0.097881
# min        0.000000
# 25%        0.051000
# 50%        0.082000
# 75%        0.136500
# max        0.457000
# Name: Perceptions of corruption, dtype: float64

# %%
Q1,Q3 = np.percentile(happy_2018['Perceptions of corruption'], [25,75])
print('Q1 is:', Q1)
print('Q3 is:', Q3)
# Out:
# Q1 is: 0.051
# Q3 is: 0.1365

# %%
#both extremes of corruption values
condi1 = (happy_2018['Perceptions of corruption'] < 0.051) | (happy_2018['Perceptions of corruption'] > 0.1365)
happy_2018_condi1 = happy_2018.loc[condi1]
extreme_head = happy_2018_condi1.head(5)
extreme_tail = happy_2018_condi1.tail(5)
extremes = pd.concat([extreme_head,extreme_tail])

# %%
fig = px.bar(extremes, x = 'Country or region', y = ["Perceptions of corruption","Score"])
fig.update_layout(barmode='group')
fig.update_layout(title_text='Country perceptions on corruption 2018')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2e093985-c858-46fa-af14-0c43b0d6714f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e093985-c858-46fa-af14-0c43b0d6714f")) {                    Plotly.newPlot(                        "2e093985-c858-46fa-af14-0c43b0d6714f",                        [{"alignmentgroup":"True","hovertemplate":"variable=Perceptions of corruption\u003cbr\u003eCountry or region=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Perceptions of corruption","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Perceptions of corruption","offsetgroup":"Perceptions of corruption","orientation":"v","showlegend":true,"textposition":"auto","x":["Finland","Norway","Denmark","Iceland","Switzerland","Ukraine","Madagascar","Afghanistan","Liberia","Rwanda"],"xaxis":"x","y":[0.393,0.34,0.408,0.138,0.357,0.011,0.049,0.036,0.03,0.444],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Score\u003cbr\u003eCountry or region=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Score","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Score","offsetgroup":"Score","orientation":"v","showlegend":true,"textposition":"auto","x":["Finland","Norway","Denmark","Iceland","Switzerland","Ukraine","Madagascar","Afghanistan","Liberia","Rwanda"],"xaxis":"x","y":[7.6320000000000014,7.5939999999999985,7.555,7.495,7.487,4.103,3.774,3.632,3.495,3.408],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[ ...

# %%
happy_2019 = happy[happy['year'] == 2019].sort_values(by = 'Overall rank')

# %%
happy_2019.shape
# Out:
# (148, 9)

# %%
Q1,Q3 = np.percentile(happy_2019['Perceptions of corruption'], [25,75])
print('Q1 is:', Q1)
print('Q3 is:', Q3)
# Out:
# Q1 is: 0.04925
# Q3 is: 0.1405

# %%
#both extremes of corruption values
condi12 = (happy_2019['Perceptions of corruption'] < 0.04925) | (happy_2019['Perceptions of corruption'] > 0.1405)
happy_2019_condi12 = happy_2019.loc[condi12]
extreme_head2 = happy_2019_condi12.head(5)
extreme_tail2 = happy_2019_condi12.tail(5)
extremes2 = pd.concat([extreme_head2,extreme_tail2])

# %%
fig = px.bar(extremes2, x = 'Country or region', y = ["Perceptions of corruption","Score"])
fig.update_layout(barmode='group')
fig.update_layout(title_text='Country perceptions on corruption 2019')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea50a0bb-1fe1-4562-9bda-18988382f863" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea50a0bb-1fe1-4562-9bda-18988382f863")) {                    Plotly.newPlot(                        "ea50a0bb-1fe1-4562-9bda-18988382f863",                        [{"alignmentgroup":"True","hovertemplate":"variable=Perceptions of corruption\u003cbr\u003eCountry or region=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Perceptions of corruption","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Perceptions of corruption","offsetgroup":"Perceptions of corruption","orientation":"v","showlegend":true,"textposition":"auto","x":["Finland","Denmark","Norway","Netherlands","Switzerland","Ukraine","Liberia","Madagascar","Rwanda","Tanzania"],"xaxis":"x","y":[0.393,0.41,0.341,0.298,0.343,0.01,0.033,0.041,0.411,0.147],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Score\u003cbr\u003eCountry or region=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Score","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Score","offsetgroup":"Score","orientation":"v","showlegend":true,"textposition":"auto","x":["Finland","Denmark","Norway","Netherlands","Switzerland","Ukraine","Liberia","Madagascar","Rwanda","Tanzania"],"xaxis":"x","y":[7.769,7.6,7.5539999999999985,7.487999999999999,7.48,4.332,3.975,3.933,3.334,3.2310000000000003],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222," ...

# %% [markdown]
# ## CONCLUSION:Wrong. As we can see that countries who have lower perception of corruption have the highest overal scores. European countries perceive corruption as less emerging in their lands compared to African countries; and the top 10 happiest countries are occupied by mostly Europeans.

# %% [markdown]
# ### **Hypothesis 2: All countries perceive themselves as generous equally.**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(happy.iloc[:,6:7].sort_values(by='Generosity', ascending=False), yticklabels=False, cbar=True, cmap='coolwarm')
plt.title("Country perceptions on generosity", fontsize =15)
plt.show()

# %%
happy_pivot = happy.pivot(index='Country or region', columns='year', values='Generosity')
happy_pivot['mean_Generosity'] = happy_pivot.mean(axis=1)
happy_pivot = happy_pivot.sort_values(by='mean_Generosity', ascending=False).drop(columns='mean_Generosity')
happy_pivot
# Out:
# year                2018   2019
# Country or region
# Haiti              0.392  0.419
# Malta              0.376  0.375
# Bhutan             0.364  0.370
# Kenya              0.352  0.372
# Thailand           0.364  0.359
# ...                  ...    ...
# Lithuania          0.026  0.043
# Botswana           0.042  0.025
# Azerbaijan         0.031  0.035
# Morocco            0.026  0.036
# Greece             0.000  0.000
#
# [153 rows x 2 columns]

# %%
happy_pivot.isnull().sum()
# Out:
# year
# 2018    5
# 2019    5
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(happy_pivot, yticklabels=False, cbar=True, cmap='coolwarm')
plt.title("Country perceptions on generosity", fontsize =15)
plt.xlabel('year', fontsize = 15)
plt.show()

# %% [markdown]
# ### CONCLUSION:  No, the countries do not see themselves as generous in an equal weight. Moreover, none of them has value over than 0,5 which means their perceptions of generosity is quite low and this is not key index to the total score.

# %% [markdown]
# ###**Hypothesis 3: Social support is the most important index of all.**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
columns_to_scale = ['GDP per capita','Social support', 'Freedom to make life choices', 'Generosity','Perceptions of corruption']
happy[columns_to_scale] = pd.DataFrame(scaler.fit_transform(happy[columns_to_scale]))
happy_scale = happy[columns_to_scale]
happy_scale
# Out:
#      GDP per capita  Social support  Freedom to make life choices  Generosity  \
# 0          0.774941        0.955556                      0.938484    0.482100
# 1          0.864608        0.947009                      0.945637    0.682578
# 2          0.802257        0.953846                      0.941345    0.677804
# 3          0.797506        1.000000                      0.932761    0.842482
# 4          0.843230        0.918803                      0.908441    0.610979
# ..              ...             ...                           ...         ...
# 291        0.618171        0.573504                      0.615165    0.059666
# 292        0.113420        0.073504                      0.597997    0.520286
# 293        0.170428        0.588889                      0.168813    0.257757
# 294        0.213183        0.202564                      0.758226    0.517900
# 295        0.282660        0.351282                      0.560801    0.658711
#
#      Perceptions of corruption
# 0                     0.859956
# 1                     0.743982
# 2                     0.892779
# 3                     0.301969
# 4                     0.781182
# ..                         ...
# 291                   0.218818
# 292                   0.194748
# 293                   0.168490
# 294                   0.899344
# 295                   0.321663
#
# [296 rows x 5 columns]

# %%
happyrest = ['Country or region', 'Overall rank', 'Score', 'year']
happy_therest = happy[happyrest]
happy_therest
# Out:
#     Country or region  Overall rank  Score  year
# 0             Finland             1  7.632  2018
# 1              Norway             2  7.594  2018
# 2             Denmark             3  7.555  2018
# 3             Iceland             4  7.495  2018
# 4         Switzerland             5  7.487  2018
# ..                ...           ...    ...   ...
# 291          Botswana           148  3.488  2019
# 292            Malawi           150  3.410  2019
# 293             Yemen           151  3.380  2019
# 294            Rwanda           152  3.334  2019
# 295          Tanzania           153  3.231  2019
#
# [296 rows x 4 columns]

# %%
fig3 = px.box(happy_scale)
fig3.update_layout(title_text='Relevance of different criteria within the same scale', title_x = 0.5)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="41bf83f4-685f-4e1e-9880-dafbd392d00d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41bf83f4-685f-4e1e-9880-dafbd392d00d")) {                    Plotly.newPlot(                        "41bf83f4-685f-4e1e-9880-dafbd392d00d",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP per capita","GDP  ...

# %% [markdown]
# CONCLUSION: Yes, it seems that Social support ranks as the most relevant criteria among all.

# %% [markdown]
# ###**Hypothesis 4: Asian countries and African countries have similar rate of freedom to make life choices.**

# %%
fig4 = px.choropleth(happy, locations="Country or region",locationmode="country names",color="Freedom to make life choices")
fig4.update_layout(title_text='Distribution of freedom to make life choices across countries', title_x = 0.45)
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0ef8b6a6-6f3d-40de-b3a1-50f74cec7b20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ef8b6a6-6f3d-40de-b3a1-50f74cec7b20")) {                    Plotly.newPlot(                        "0ef8b6a6-6f3d-40de-b3a1-50f74cec7b20",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country or region=%{location}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Finland","Norway","Denmark","Iceland","Switzerland","Netherlands","Canada","New Zealand","Sweden","Australia","United Kingdom","Austria","Costa Rica","Ireland","Germany","Belgium","Luxembourg","United States","Israel","Czech Republic","Malta","France","Mexico","Chile","Taiwan","Panama","Brazil","Argentina","Guatemala","Uruguay","Qatar","Saudi Arabia","Singapore","Malaysia","Spain","Colombia","Trinidad & Tobago","Slovakia","El Salvador","Nicaragua","Poland","Bahrain","Uzbekistan","Kuwait","Thailand","Italy","Ecuador","Belize","Lithuania","Slovenia","Romania","Latvia","Japan","Mauritius","Jamaica","South Korea","Northern Cyprus","Russia","Kazakhstan","Cyprus","Bolivia","Estonia","Paraguay","Peru","Kosovo","Moldova","Turkmenistan","Hungary","Libya","Philippines","Honduras","Belarus","Turkey","Pakistan","Hong Kong","Portugal","Serbia","Greece","Lebanon","Montenegro","Croatia","Dominican Republic","Algeria","Morocco","China","Azerbaijan","Tajikistan","Macedonia","Jordan","Nigeria","Kyrgyzstan","Bosnia and Herzegovina","Mongolia","Vietnam","Bhutan","Somalia","Cameroon","Bulgaria","Nepal","Venezuela","Gabon","Palestinian Territories","South Africa","Iran","Ivory Coast","Ghana","Senegal","Laos","Tunisia","Albania","Sierra Leone","Congo (Brazzaville)","Bangladesh","Sri Lanka","Iraq","Mali","Namibia","Cambodia","Burkina Faso","Egypt","Mozambique","Kenya","Zambia","Mauritania","Ethiopia","Georgia","Armenia","Chad","Congo (Kinshasa)","India","Niger","Uganda","Ukraine","Togo","Guinea","Lesotho","Madagascar","Zimbabwe","Afghanistan","Botswana","Malawi","Haiti","Liberia","Rwanda","Yemen","Tanzania","South Sudan","Burundi","Finland","Denmark","Norway","Iceland","Netherlands","Switzerland","Sweden","New Zealand","Canada","Austria","Australia","Costa Rica","Israel","Luxembourg","United Kingdom","Ireland","Germany","Belgium","United States","Czech Republic","United Arab Emirates","Malta","Mexico","France","Taiwan","Chile","Guatemala","Saudi Arabia","Qatar","Spain","Panama","Brazil","Uruguay","Singapore","El Salvador","Italy","Bahrain","Slovakia","Trinidad & Tobago","Poland","Uzbekistan","Lithuania","Colombia","Slovenia","Nicaragua","Kosovo","Argentina","Romania","Cyprus","Ecuador","Kuwait","Thailand","Latvia","South Korea","Estonia","Jamaica","Mauritius","Japan","Honduras","Kazakhstan","Bolivia","Hungary","Paraguay","Northern Cyprus","Peru","Portugal","Pakistan","Russia","Philippines","Serbia","Moldova","Libya","Montenegro","Tajikistan","Croatia","Hong Kong","Dominican Republic","Bosnia and Herzegovina","Turkey","Malaysia","Belarus","Greece","Mongolia","North Macedonia","Nigeria","Kyrgyzstan","Turkmenistan","Algeria","Morocco","Azerbaijan","Lebanon","China","Vietnam","Bhutan","Cameroon","Bulgaria","Ghana","Ivory Coast","Nepal","Jordan","Congo (Brazzaville)","Gabon","Laos","South Africa","Albania","Venezuela","Cambodia","Palestinian Territories","Senegal","Somalia","Namibia","Niger","Burkina Faso","Armenia","Iran","Guinea","Georgia","Gambia","Kenya","Mauritania","Mozambique","Tunisia","Bangladesh","Iraq","Congo (Kinshasa)","Mali","Sierra Leone","Sri Lanka","Chad","Ukraine","Ethiopia","Swaziland","Uganda","Egypt","Zambia","Togo","India","Liberia","Comoros","Madagascar","Lesotho","Z ...

# %%
fig42 = px.scatter_geo(happy, locations="Country or region", locationmode="country names", color="Freedom to make life choices", size='Freedom to make life choices')

fig42.update_layout(title_text = 'Freedom to make life choices in the world')

fig42.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aa353493-20c6-4ec9-8553-edfe82396a9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa353493-20c6-4ec9-8553-edfe82396a9f")) {                    Plotly.newPlot(                        "aa353493-20c6-4ec9-8553-edfe82396a9f",                        [{"geo":"geo","hovertemplate":"Freedom to make life choices=%{marker.color}\u003cbr\u003eCountry or region=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","locationmode":"country names","locations":["Finland","Norway","Denmark","Iceland","Switzerland","Netherlands","Canada","New Zealand","Sweden","Australia","United Kingdom","Austria","Costa Rica","Ireland","Germany","Belgium","Luxembourg","United States","Israel","Czech Republic","Malta","France","Mexico","Chile","Taiwan","Panama","Brazil","Argentina","Guatemala","Uruguay","Qatar","Saudi Arabia","Singapore","Malaysia","Spain","Colombia","Trinidad & Tobago","Slovakia","El Salvador","Nicaragua","Poland","Bahrain","Uzbekistan","Kuwait","Thailand","Italy","Ecuador","Belize","Lithuania","Slovenia","Romania","Latvia","Japan","Mauritius","Jamaica","South Korea","Northern Cyprus","Russia","Kazakhstan","Cyprus","Bolivia","Estonia","Paraguay","Peru","Kosovo","Moldova","Turkmenistan","Hungary","Libya","Philippines","Honduras","Belarus","Turkey","Pakistan","Hong Kong","Portugal","Serbia","Greece","Lebanon","Montenegro","Croatia","Dominican Republic","Algeria","Morocco","China","Azerbaijan","Tajikistan","Macedonia","Jordan","Nigeria","Kyrgyzstan","Bosnia and Herzegovina","Mongolia","Vietnam","Bhutan","Somalia","Cameroon","Bulgaria","Nepal","Venezuela","Gabon","Palestinian Territories","South Africa","Iran","Ivory Coast","Ghana","Senegal","Laos","Tunisia","Albania","Sierra Leone","Congo (Brazzaville)","Bangladesh","Sri Lanka","Iraq","Mali","Namibia","Cambodia","Burkina Faso","Egypt","Mozambique","Kenya","Zambia","Mauritania","Ethiopia","Georgia","Armenia","Chad","Congo (Kinshasa)","India","Niger","Uganda","Ukraine","Togo","Guinea","Lesotho","Madagascar","Zimbabwe","Afghanistan","Botswana","Malawi","Haiti","Liberia","Rwanda","Yemen","Tanzania","South Sudan","Burundi","Finland","Denmark","Norway","Iceland","Netherlands","Switzerland","Sweden","New Zealand","Canada","Austria","Australia","Costa Rica","Israel","Luxembourg","United Kingdom","Ireland","Germany","Belgium","United States","Czech Republic","United Arab Emirates","Malta","Mexico","France","Taiwan","Chile","Guatemala","Saudi Arabia","Qatar","Spain","Panama","Brazil","Uruguay","Singapore","El Salvador","Italy","Bahrain","Slovakia","Trinidad & Tobago","Poland","Uzbekistan","Lithuania","Colombia","Slovenia","Nicaragua","Kosovo","Argentina","Romania","Cyprus","Ecuador","Kuwait","Thailand","Latvia","South Korea","Estonia","Jamaica","Mauritius","Japan","Honduras","Kazakhstan","Bolivia","Hungary","Paraguay","Northern Cyprus","Peru","Portugal","Pakistan","Russia","Philippines","Serbia","Moldova","Libya","Montenegro","Tajikistan","Croatia","Hong Kong","Dominican Republic","Bosnia and Herzegovina","Turkey","Malaysia","Belarus","Greece","Mongolia","North Macedonia","Nigeria","Kyrgyzstan","Turkmenistan","Algeria","Morocco","Azerbaijan","Lebanon","China","Vietnam","Bhutan","Cameroon","Bulgaria","Ghana","Ivory Coast","Nepal","Jordan","Congo (Brazzaville)","Gabon","Laos","South Africa","Albania","Venezuela","Cambodia","Palestinian Territories","Senegal","Somalia","Namibia","Niger","Burkina Faso","Armenia","Iran","Guinea","Georgia","Gambia","Kenya","Mauritania","Mozambique","Tunisia","Bangladesh","Iraq","Congo (Kinshasa)","Mali","Sierra Leone","Sri Lanka","Chad","Ukraine","Ethiopia","Swaziland","Uganda","Egypt","Zambia","Togo","India","Liberia","Comoros","Madagascar","Lesotho ...

# %% [markdown]
# ## CONCLUSION : No, overall Asian countries are enjoying higher freedom of choice than African countries.

# %% [markdown]
# ###**Hypothesis 5: Social support and sense of freedom are correlated.**

# %%
happy2018_corr = happy_2018.corr(numeric_only=True)

# %%
sns.heatmap(happy2018_corr,vmax=1, vmin=-1,annot = True, center=0, cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: >

# %%
happy_comb_social2 = happy_combined[happy_combined['year'] == 2018].sort_values(by='Social support', ascending=True).head(10)
happy_comb_social2
# Out:
#     Country or region  Overall rank  Score  year  GDP per capita  \
# 133              Togo           139  3.999  2018        0.153800
# 138       Afghanistan           145  3.632  2018        0.197150
# 140            Malawi           147  3.587  2018        0.110451
# 125           Georgia           128  4.340  2018        0.506532
# 146       South Sudan           154  3.254  2018        0.200119
# 147           Burundi           156  2.905  2018        0.054038
# 95            Somalia            98  4.982  2018        0.000000
# 141             Haiti           148  3.582  2018        0.187055
# 129             India           133  4.190  2018        0.428147
# 103              Iran           106  4.707  2018        0.628860
#
#      Social support  Freedom to make life choices  Generosity  \
# 133        0.000000                      0.585122    0.377088
# 138        0.053846                      0.085837    0.455847
# 140        0.057265                      0.723891    0.501193
# 125        0.100855                      0.500715    0.090692
# 146        0.114530                      0.124464    0.534606
# 147        0.130769                      0.057225    0.355609
# 95         0.203419                      0.928469    0.568019
# 141        0.205128                      0.000000    0.935561
# 129        0.233333                      0.735336    0.410501
# 103        0.253846                      0.620887    0.673031
#
#      Perceptions of corruption
# 133                   0.221007
# 138                   0.078775
# 140                   0.175055
# 125                   0.470460
# 146                   0.231947
# 147                   0.166302
# 95                    0.617068
# 141                   0.227571
# 129                   0.203501
# 103                   0.282276

# %%
fig54= px.scatter_3d(happy_comb_social, x='GDP per capita', y='Social support', z='Freedom to make life choices',color = 'Country or region')
fig54.update_layout(title_text='Top 10 countries based on Social Support', title_x=0.5)
fig54.show()
fig54.write_html("file.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee16aebb-2650-48d7-8e72-80a0d5888956" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee16aebb-2650-48d7-8e72-80a0d5888956")) {                    Plotly.newPlot(                        "ee16aebb-2650-48d7-8e72-80a0d5888956",                        [{"hovertemplate":"Country or region=Iceland\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iceland","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Iceland","scene":"scene","showlegend":true,"x":[0.7975059382422803],"y":[1.0],"z":[0.932761087267525],"type":"scatter3d"},{"hovertemplate":"Country or region=New Zealand\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"New Zealand","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"New Zealand","scene":"scene","showlegend":true,"x":[0.7529691211401425],"y":[0.9632478632478633],"z":[0.9213161659513591],"type":"scatter3d"},{"hovertemplate":"Country or region=Finland\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Finland","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Finland","scene":"scene","showlegend":true,"x":[0.7749406175771971],"y":[0.9555555555555558],"z":[0.938483547925608],"type":"scatter3d"},{"hovertemplate":"Country or region=Denmark\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Denmark","scene":"scene","showlegend":true,"x":[0.8022565320665083],"y":[0.9538461538461541],"z":[0.9413447782546495],"type":"scatter3d"},{"hovertemplate":"Country or region=Uzbekistan\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Uzbekistan","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Uzbekistan","scene":"scene","showlegend":true,"x":[0.4269596199524941],"y":[0.9487179487179488],"z":[1.0000000000000002],"type":"scatter3d"},{"hovertemplate":"Country or region=Ireland\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ireland","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Ireland","scene":"scene","showlegend":true,"x":[0.8598574821852732],"y":[0.9478632478632482],"z":[0.8426323319027181],"type":"scatter3d"},{"hovertemplate":"Country or region=Norway\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Norway","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Norway","scene":"scene","showlegend":true,"x":[0.8646080760095012],"y":[0.9470085470085471],"z":[0.9456366237482117],"type":"scatter3d"},{"hovertemplate":"Country or region=Australia\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Australia","scene":"scene","showlegend":true,"x":[0.7957244655581948],"y":[0.9393162393162396],"z":[0.88984263233 ...

# %%
fig55= px.scatter_3d(happy_comb_social2, x='GDP per capita', y='Social support', z='Freedom to make life choices',color = 'Country or region')
fig55.update_layout(title_text='Bottom 10 countries based on Social Support', title_x=0.5)
fig55.show()
fig55.write_html("file.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="21e09d31-38c2-49a7-a8d0-3e36bc9077b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21e09d31-38c2-49a7-a8d0-3e36bc9077b7")) {                    Plotly.newPlot(                        "21e09d31-38c2-49a7-a8d0-3e36bc9077b7",                        [{"hovertemplate":"Country or region=Togo\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Togo","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Togo","scene":"scene","showlegend":true,"x":[0.15380047505938244],"y":[0.0],"z":[0.5851216022889842],"type":"scatter3d"},{"hovertemplate":"Country or region=Afghanistan\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Afghanistan","scene":"scene","showlegend":true,"x":[0.19714964370546317],"y":[0.05384615384615393],"z":[0.08583690987124465],"type":"scatter3d"},{"hovertemplate":"Country or region=Malawi\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Malawi","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Malawi","scene":"scene","showlegend":true,"x":[0.11045130641330166],"y":[0.05726495726495734],"z":[0.7238912732474965],"type":"scatter3d"},{"hovertemplate":"Country or region=Georgia\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Georgia","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Georgia","scene":"scene","showlegend":true,"x":[0.5065320665083135],"y":[0.10085470085470094],"z":[0.5007153075822603],"type":"scatter3d"},{"hovertemplate":"Country or region=South Sudan\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Sudan","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"South Sudan","scene":"scene","showlegend":true,"x":[0.2001187648456057],"y":[0.11452991452991457],"z":[0.12446351931330471],"type":"scatter3d"},{"hovertemplate":"Country or region=Burundi\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Burundi","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Burundi","scene":"scene","showlegend":true,"x":[0.054038004750593824],"y":[0.13076923076923086],"z":[0.05722460658082975],"type":"scatter3d"},{"hovertemplate":"Country or region=Somalia\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Somalia","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Somalia","scene":"scene","showlegend":true,"x":[0.0],"y":[0.20341880341880358],"z":[0.9284692417739628],"type":"scatter3d"},{"hovertemplate":"Country or region=Haiti\u003cbr\u003eGDP per capita=%{x}\u003cbr\u003eSocial support=%{y}\u003cbr\u003eFreedom to make life choices=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haiti","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Haiti","scene":"scene","showlegend":true,"x":[0.1870546318289786],"y":[0.2051282051282053],"z":[0.0],"type":"scatter3d"},{"hov ...

# %% [markdown]
# ### CONCLUSION : Social support and freedom have low degree of correlation with each other (0.4).

# %% [markdown]
# STRUGGLES
#
# 1. Incomplete data
# 2. Trying to find the most representative visualization to support the hypothesis
# 3. Translate what we have in mind to a piece of code

# %% [markdown]
# LESSONS LEARNT
# 1. To see the actual results and added value of data analysis for companies and organizations
# 2. Finding measurable and specific conclusions based on tested hypotheses
# 3. See the bigger picture based on reduced samples
